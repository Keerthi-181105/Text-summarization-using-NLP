# %% [markdown]
# <a href="https://colab.research.google.com/github/Keerthi-181105/Text-summarization-using-NLP/blob/main/textsumNLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wikipedia
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11678 sha256=fcc4ebcd613f26e2ab583c104bef46a502f984b900dca739fc4d960bfdcbc716
#   Stored in directory: /root/.cache/pip/wheels/63/47/7c/a9688349aa74d228ce0a9023229c6c0ac52ca2a40fe87679b8
# Successfully built wikipedia
# ...

# %%
import wikipedia

# %%
text=wikipedia.summary('Healthcare')

# %%
print(text)
# Out:
# Health care, or healthcare, is the improvement or maintenance of health via the prevention, diagnosis, treatment, amelioration or cure of disease, illness, injury, and other physical and mental impairments in people. Health care is delivered by health professionals and allied health fields. Medicine, dentistry, pharmacy, midwifery, nursing, optometry, audiology, psychology, occupational therapy, physical therapy, athletic training, and other health professions all constitute health care. The term includes work done in providing primary care, secondary care, tertiary care, mental health care and public health.
# ...

# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 91.6 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
stopwords=list(STOP_WORDS)

# %%
nlp=spacy.load('en_core_web_sm')

# %%
doc=nlp(text)

# %%
print(doc)
# Out:
# Health care, or healthcare, is the improvement or maintenance of health via the prevention, diagnosis, treatment, amelioration or cure of disease, illness, injury, and other physical and mental impairments in people. Health care is delivered by health professionals and allied health fields. Medicine, dentistry, pharmacy, midwifery, nursing, optometry, audiology, psychology, occupational therapy, physical therapy, athletic training, and other health professions all constitute health care. The term includes work done in providing primary care, secondary care, tertiary care, mental health care and public health.
# ...

# %%
tokens=[token.text for token in doc]
print(tokens)
# Out:
# ['Health', 'care', ',', 'or', 'healthcare', ',', 'is', 'the', 'improvement', 'or', 'maintenance', 'of', 'health', 'via', 'the', 'prevention', ',', 'diagnosis', ',', 'treatment', ',', 'amelioration', 'or', 'cure', 'of', 'disease', ',', 'illness', ',', 'injury', ',', 'and', 'other', 'physical', 'and', 'mental', 'impairments', 'in', 'people', '.', 'Health', 'care', 'is', 'delivered', 'by', 'health', 'professionals', 'and', 'allied', 'health', 'fields', '.', 'Medicine', ',', 'dentistry', ',', 'pharmacy', ',', 'midwifery', ',', 'nursing', ',', 'optometry', ',', 'audiology', ',', 'psychology', ',', 'occupational', 'therapy', ',', 'physical', 'therapy', ',', 'athletic', 'training', ',', 'and', 'other', 'health', 'professions', 'all', 'constitute', 'health', 'care', '.', 'The', 'term', 'includes', 'work', 'done', 'in', 'providing', 'primary', 'care', ',', 'secondary', 'care', ',', 'tertiary', 'care', ',', 'mental', 'health', 'care', 'and', 'public', 'health', '.', '\n', 'Access', 'to', 'heal
# ...

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
punctuation=punctuation+'\n'
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n'

# %%
word_frequencies={}
for word in doc:
  if word.text.lower() not in stopwords:
    if word.text.lower() not in punctuation:
      if word.text not in word_frequencies.keys():
        word_frequencies[word.text]=1
      else:
        word_frequencies[word.text]+=1

# %%
print(word_frequencies)
# Out:
# {'Health': 5, 'care': 16, 'healthcare': 1, 'improvement': 1, 'maintenance': 1, 'health': 22, 'prevention': 1, 'diagnosis': 1, 'treatment': 1, 'amelioration': 1, 'cure': 1, 'disease': 2, 'illness': 1, 'injury': 1, 'physical': 3, 'mental': 3, 'impairments': 1, 'people': 2, 'delivered': 1, 'professionals': 1, 'allied': 1, 'fields': 1, 'Medicine': 1, 'dentistry': 1, 'pharmacy': 1, 'midwifery': 1, 'nursing': 1, 'optometry': 1, 'audiology': 1, 'psychology': 1, 'occupational': 1, 'therapy': 2, 'athletic': 1, 'training': 1, 'professions': 1, 'constitute': 1, 'term': 1, 'includes': 1, 'work': 2, 'providing': 1, 'primary': 1, 'secondary': 1, 'tertiary': 1, 'public': 1, 'Access': 1, 'vary': 1, 'countries': 1, 'communities': 1, 'individuals': 1, 'influenced': 1, 'social': 1, 'economic': 1, 'conditions': 1, 'policies': 2, 'Providing': 1, 'services': 5, 'means': 1, 'timely': 1, 'use': 3, 'personal': 2, 'achieve': 1, 'best': 1, 'possible': 1, 'outcomes': 1, 'Factors': 1, 'consider': 1, 'terms': 1, 
# ...

# %%
max_frequency=max(word_frequencies.values())
max_frequency
# Out:
# 22

# %%
for word in word_frequencies.keys():
  word_frequencies[word]=word_frequencies[word]/max_frequency

print(word_frequencies)
# Out:
# {'Health': 0.22727272727272727, 'care': 0.7272727272727273, 'healthcare': 0.045454545454545456, 'improvement': 0.045454545454545456, 'maintenance': 0.045454545454545456, 'health': 1.0, 'prevention': 0.045454545454545456, 'diagnosis': 0.045454545454545456, 'treatment': 0.045454545454545456, 'amelioration': 0.045454545454545456, 'cure': 0.045454545454545456, 'disease': 0.09090909090909091, 'illness': 0.045454545454545456, 'injury': 0.045454545454545456, 'physical': 0.13636363636363635, 'mental': 0.13636363636363635, 'impairments': 0.045454545454545456, 'people': 0.09090909090909091, 'delivered': 0.045454545454545456, 'professionals': 0.045454545454545456, 'allied': 0.045454545454545456, 'fields': 0.045454545454545456, 'Medicine': 0.045454545454545456, 'dentistry': 0.045454545454545456, 'pharmacy': 0.045454545454545456, 'midwifery': 0.045454545454545456, 'nursing': 0.045454545454545456, 'optometry': 0.045454545454545456, 'audiology': 0.045454545454545456, 'psychology': 0.045454545454545
# ...

# %%
sentence_tokens=[sent for sent in doc.sents]
sentence_list=[]
sentence_list=sentence_tokens

print(sentence_tokens)
# Out:
# [Health care, or healthcare, is the improvement or maintenance of health via the prevention, diagnosis, treatment, amelioration or cure of disease, illness, injury, and other physical and mental impairments in people., Health care is delivered by health professionals and allied health fields., Medicine, dentistry, pharmacy, midwifery, nursing, optometry, audiology, psychology, occupational therapy, physical therapy, athletic training, and other health professions all constitute health care., The term includes work done in providing primary care, secondary care, tertiary care, mental health care and public health.
# ...

# %%
sentence_scores={}

for sent in sentence_tokens:
  for word in sent:
    if word.text.lower() in word_frequencies.keys():
      if sent not in sentence_scores.keys():
        sentence_scores[sent]=word_frequencies[word.text.lower()]
      else:
        sentence_scores[sent]+=word_frequencies[word.text.lower()]

sentence_scores
# Out:
# {Health care, or healthcare, is the improvement or maintenance of health via the prevention, diagnosis, treatment, amelioration or cure of disease, illness, injury, and other physical and mental impairments in people.: 3.6818181818181808,
#  Health care is delivered by health professionals and allied health fields.: 3.9090909090909087,
#  Medicine, dentistry, pharmacy, midwifery, nursing, optometry, audiology, psychology, occupational therapy, physical therapy, athletic training, and other health professions all constitute health care.: 3.590909090909091,
#  The term includes work done in providing primary care, secondary care, tertiary care, mental health care and public health.: 5.454545454545455,
#  Access to health care may vary across countries, communities, and individuals, influenced by social and economic conditions and health policies.: 3.227272727272727,
# ...

# %%
from heapq import nlargest

# %%
select_length=int(len(sentence_tokens)*0.3)

# %%
select_length
# Out:
# 3

# %%
len(sentence_tokens)
# Out:
# 13

# %%
summary=nlargest(select_length,sentence_scores,key=sentence_scores.get)
summary
# Out:
# [Factors to consider in terms of health care access include financial limitations (such as insurance coverage), geographical and logistical barriers (such as additional transportation costs and the ability to take paid time off work to use such services), sociocultural expectations, and personal limitations (lack of ability to communicate with health care providers, poor health literacy, low income).,
#  The term includes work done in providing primary care, secondary care, tertiary care, mental health care and public health.,
#  According to the World Health Organization (WHO), a well-functioning health care system requires a financing mechanism, a well-trained and adequately paid workforce, reliable information on which to base decisions and policies, and well-maintained health facilities to deliver quality medicines and technologies.]

# %%
final_summary=""

for sent in sentence_list:
  if sent in summary:
    final_summary+=sent.text+" "

final_summary
# Out:
# 'The term includes work done in providing primary care, secondary care, tertiary care, mental health care and public health.\n Factors to consider in terms of health care access include financial limitations (such as insurance coverage), geographical and logistical barriers (such as additional transportation costs and the ability to take paid time off work to use such services), sociocultural expectations, and personal limitations (lack of ability to communicate with health care providers, poor health literacy, low income). According to the World Health Organization (WHO), a well-functioning health care system requires a financing mechanism, a well-trained and adequately paid workforce, reliable information on which to base decisions and policies, and well-maintained health facilities to deliver quality medicines and technologies.\n '

# %%
len(text)
# Out:
# 2319

# %%
len(final_summary)
# Out:
# 842
